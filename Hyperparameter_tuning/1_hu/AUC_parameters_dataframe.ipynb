# %%
import numpy as np
import pandas as pd

# %%
# Read in tab-separated file into DataFrame
df = pd.read_csv('AUC_parameters.txt', sep='\t')

# %%
# Sort the DataFrame by the maximum value of AUC (validation)
AUCval_df = df.sort_values(by='AUC_valid', ascending=False)
AUCval_df
# Out:
#         Act   Reg Batch  Balancing  AUC_valid  AUC_test
# 7      relu  0.01   128      False   0.782217  0.789158
# 3      relu  None   128      False   0.781705  0.787317
# 1      relu  None  None      False   0.780409  0.788296
# 5      relu  0.01  None      False   0.780402  0.788345
# 2      relu  None   128       True   0.773996  0.785103
# 6      relu  0.01   128       True   0.773991  0.785111
# 4      relu  0.01  None       True   0.772325  0.784552
# 0      relu  None  None       True   0.772173  0.784153
# 11  sigmoid  None   128      False   0.754402  0.773821
# 15  sigmoid  0.01   128      False   0.754399  0.773819
# 9   sigmoid  None  None      False   0.752584  0.772634
# 13  sigmoid  0.01  None      False   0.752584  0.772634
# 14  sigmoid  0.01   128       True   0.715275  0.739825
# 10  sigmoid  None   128       True   0.715275  0.739825
# 12  sigmoid  0.01  None       True   0.712911  0.737056
# 8   sigmoid  None  None       True   0.712911  0.737056

# %%
# Sort the DataFrame by the maximum value of AUC (test)
AUCtest_df = df.sort_values(by='AUC_test', ascending=False)
AUCtest_df
# Out:
#         Act   Reg Batch  Balancing  AUC_valid  AUC_test
# 7      relu  0.01   128      False   0.782217  0.789158
# 5      relu  0.01  None      False   0.780402  0.788345
# 1      relu  None  None      False   0.780409  0.788296
# 3      relu  None   128      False   0.781705  0.787317
# 6      relu  0.01   128       True   0.773991  0.785111
# 2      relu  None   128       True   0.773996  0.785103
# 4      relu  0.01  None       True   0.772325  0.784552
# 0      relu  None  None       True   0.772173  0.784153
# 11  sigmoid  None   128      False   0.754402  0.773821
# 15  sigmoid  0.01   128      False   0.754399  0.773819
# 9   sigmoid  None  None      False   0.752584  0.772634
# 13  sigmoid  0.01  None      False   0.752584  0.772634
# 14  sigmoid  0.01   128       True   0.715275  0.739825
# 10  sigmoid  None   128       True   0.715275  0.739825
# 12  sigmoid  0.01  None       True   0.712911  0.737056
# 8   sigmoid  None  None       True   0.712911  0.737056
